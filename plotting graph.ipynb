# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.arange(0.5, 5, 1)
data
h
# Out:
#      0
# 0  0.5
# 1  1.5
# 2  2.5
# 3  3.5
# 4  4.5

# %%
data**2
# Out:
# array([ 0.25,  2.25,  6.25, 12.25, 20.25])

# %%
plt.plot([data], [data**2], 'ro')
plt.title('this is first plotting graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
plt.close()

# %%
plt.plot(data, data**3, 'ro')
plt.plot(data, data**4, 'yo')
plt.plot(data, data**5, 'g--')
plt.show()

# %%
plt.plot([1,2,3,4,5], [3,2,4,2,1], 'r--')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
plt.close()

# %%
data1 = {'sales': np.arange(1, 10, 2),
        'product' : np.arange(5, 15, 2)}
df = pd.DataFrame(data1)
df
# Out:
#    sales  product
# 0      1        5
# 1      3        7
# 2      5        9
# 3      7       11
# 4      9       13

# %%
df.plot.area()
