# %%
import pandas as pd

# %%
df = pd.read_csv('envitonment.csv')

# %%
dt = pd.date_range('02-01-2019','02-10-2019')
dt2 = pd.DatetimeIndex(dt)
print(dt2)
# Out:
# DatetimeIndex(['2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04',
#                '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08',
#                '2019-02-09', '2019-02-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.insert(0, 'date', dt2)
df
# Out:
#         date    city temprature windspeed   event
# 0 2019-02-01  mumbai         14         5  summer
# 1 2019-02-02  paries         12       488    rain
# 2 2019-02-03  mumbai        12f        11  summer
# 3 2019-02-04  gujrat         12        15    rain
# 4 2019-02-05  paries         51     15mph  summer
# 5 2019-02-06  mumbai        124     15mph    rain
# 6 2019-02-07  paries        44f     12mph  summer
# 7 2019-02-08  gujrat         22        25    rain
# 8 2019-02-09  gujrat         41     11mph  summer
# 9 2019-02-10  paries        12c        15  summer

# %%
# pivot table having some arguments like df.pivot(index, columns, values)

# %%
df.pivot(index = 'city',columns ='date', values='temprature').fillna(0) #
# Out:
# date   2019-02-01 2019-02-02 2019-02-03 2019-02-04 2019-02-05 2019-02-06  \
# city
# gujrat          0          0          0         12          0          0
# mumbai         14          0        12f          0          0        124
# paries          0         12          0          0         51          0
#
# date   2019-02-07 2019-02-08 2019-02-09 2019-02-10
# city
# gujrat          0         22         41          0
# mumbai          0          0          0          0
# paries        44f          0          0        12c

# %%
df
# Out:
#         date    city temprature windspeed   event
# 0 2019-02-01  mumbai         14         5  summer
# 1 2019-02-02  paries         12       488    rain
# 2 2019-02-03  mumbai        12f        11  summer
# 3 2019-02-04  gujrat         12        15    rain
# 4 2019-02-05  paries         51     15mph  summer
# 5 2019-02-06  mumbai        124     15mph    rain
# 6 2019-02-07  paries        44f     12mph  summer
# 7 2019-02-08  gujrat         22        25    rain
# 8 2019-02-09  gujrat         41     11mph  summer
# 9 2019-02-10  paries        12c        15  summer

# %%
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#         date    city temprature windspeed   event
# 0 2019-02-01  mumbai         14         5  summer
# 1 2019-02-02  paries         12       488    rain
# 2 2019-02-03  mumbai        12f        11  summer
# 3 2019-02-04  gujrat         12        15    rain
# 4 2019-02-05  paries         51     15mph  summer
# 5 2019-02-06  mumbai        124     15mph    rain
# 6 2019-02-07  paries        44f     12mph  summer
# 7 2019-02-08  gujrat         22        25    rain
# 8 2019-02-09  gujrat         41     11mph  summer
# 9 2019-02-10  paries        12c        15  summer

# %%
df.pivot_table(index = 'city', columns = 'temprature')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93f7b16d280c> in <module>
# ----> 1 df.pivot_table(index = 'city', columns = 'temprature')
#
# NameError: name 'df' is not defined

# %%
df2 = pd.read_csv('titanic.csv')
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.pivot(index= 'PassengerId', columns='Cabin', values = 'Age')
# Out:
# Cabin         NaN  A10  A14  A16  A19  A20  A23   A24  A26  A31  ...  E8  \
# PassengerId                                                      ...
# 1            22.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 2             NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 3            26.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 4             NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 5            35.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 6             NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 7             NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 8             2.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 9            27.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 10           14.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# 11            NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN  NaN  ... NaN
# ...
